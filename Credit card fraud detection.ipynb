# %% [markdown]
# # Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading the dataset to a pandas DataFra
credit_card_data = pd.read_csv(r"D:\Datasets\creditcard.csv")

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced
#
# 0--> Normal Transaction
#
#
# 1-->Fraudulent Transaction

# %%
# saparating the data for analysis
legit =credit_card_data[credit_card_data.Class==0]
fraud =credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# statistical measure of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transaction
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under Sampling
#
# build a simple dataset containing similar distribution of normal  transactions and Fraudulent Transactions.
#
# Number of fraudulent transaction--> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# concatenating two dataFrames

# %%
new_dataset = pd.concat([legit_sample,fraud], axis = 0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 198787  132653.0 -0.350046  0.590077  1.806191 -0.591011  0.470288  0.281675
# 25547    33661.0  0.767282 -1.563103 -0.275508 -0.694668 -1.021051 -0.233601
# 103160   68528.0  1.164709 -0.629189  0.754346 -0.018885 -0.898711  0.382005
# 227343  145037.0  1.734894 -0.776613 -1.509906  0.256917  0.294257  0.425822
# 127303   78285.0 -2.474410 -1.673755 -0.799080  1.483531  4.354786 -3.886500
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 198787  0.526714 -0.015361 -0.026944  ... -0.106818 -0.100232 -0.099136
# 25547  -0.052729 -0.095952 -1.032496  ... -0.207315 -0.668381 -0.229531
# 103160 -0.825347  0.324120  1.211579  ... -0.233501 -0.582944 -0.045654
# 227343 -0.045749  0.012394  0.496704  ...  0.051228 -0.135291 -0.036600
# 127303 -0.932674  0.126474 -0.604355  ...  0.304263 -0.120424  0.547297
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96050.843496  0.059619  0.044400  0.057910 -0.033633  0.038802
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.052733 -0.017905 -0.005258  0.011829  ... -0.010163  0.041874
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.015917 -0.005790  0.018741 -0.008133  0.022033  0.000949  0.000521
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       79.733760
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# spliting the data into Features & Targets

# %%
X =  new_dataset.drop(columns='Class', axis = 1)
Y =  new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 198787  132653.0 -0.350046  0.590077  1.806191 -0.591011  0.470288  0.281675
# 25547    33661.0  0.767282 -1.563103 -0.275508 -0.694668 -1.021051 -0.233601
# 103160   68528.0  1.164709 -0.629189  0.754346 -0.018885 -0.898711  0.382005
# 227343  145037.0  1.734894 -0.776613 -1.509906  0.256917  0.294257  0.425822
# 127303   78285.0 -2.474410 -1.673755 -0.799080  1.483531  4.354786 -3.886500
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 198787    0
# 25547     0
# 103160    0
# 227343    0
# 127303    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# split the data into Training & Testing data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,stratify = Y,random_state = 2 )

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# Model Training
#
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the logistic regression model with training data
model.fit(X_train,Y_train)
# Out:
# C:\Users\bhara\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print("Accuracy on Training data: ", training_data_accuracy)
# Out:
# Accuracy on Training data:  0.9479034307496823

# %%
# accuracy on test data
X_test_pred =  model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_pred,Y_test)

# %%
print("Accuracy on test data:", testing_data_accuracy)
# Out:
# Accuracy on test data: 0.9390862944162437

# %% [markdown]
# With new dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
# Loading the dataset to a pandas DataFra
cc_data = pd.read_csv(r"D:\bharat\fraudTest.csv")

# %%
cc_data.head(20)
# Out:
#     category     amt  gender  city  state    zip      lat      long  city_pop  \
# 0         10    2.86       1   157     39  29209  33.9659  -80.9355    333497
# 1         10   29.84       0    16     43  84002  40.3207 -110.4360       302
# 2          5   41.28       0    61     33  11710  40.6729  -73.5365     34496
# 3          9   60.05       1   764      8  32780  28.5697  -80.8191     54767
# 4         13    3.19       1   247     21  49632  44.2529  -85.0170      1126
# 5          7   19.55       0    90     33  14816  42.1939  -76.7361       520
# 6          5  133.93       0   117      4  95528  40.5070 -123.9743      1139
# 7         10   10.37       0   725     40  57374  43.7557  -97.5936       343
# 8         12    4.37       1   503     37  16858  41.0001  -78.2357      3688
# 9          1   66.54       0   624     42  76678  31.6591  -96.8094       263
# 10         1    7.01       1   824     16  40077  38.4921  -85.4524       564
# ...

# %%
cc_data = cc_data.drop(columns= ["trans_num","Unnamed: 0","trans_date_trans_time","cc_num","merchant","first","last","street","dob"], axis = 1)

# %%
cc_data.head()
# Out:
#          category    amt gender        city state    zip      lat      long  \
# 0   personal_care   2.86      M    Columbia    SC  29209  33.9659  -80.9355
# 1   personal_care  29.84      F     Altonah    UT  84002  40.3207 -110.4360
# 2  health_fitness  41.28      F    Bellmore    NY  11710  40.6729  -73.5365
# 3        misc_pos  60.05      M  Titusville    FL  32780  28.5697  -80.8191
# 4          travel   3.19      M    Falmouth    MI  49632  44.2529  -85.0170
#
#    city_pop                     job   unix_time  merch_lat  merch_long  \
# 0    333497     Mechanical engineer  1371816865  33.986391  -81.200714
# 1       302  Sales professional, IT  1371816873  39.450498 -109.960431
# 2     34496       Librarian, public  1371816893  40.495810  -74.196111
# 3     54767            Set designer  1371816915  28.812398  -80.883061
# 4      1126      Furniture designer  1371816917  44.959148  -85.884734
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
cc_data.isnull().sum()
# Out:
# category      0
# amt           0
# gender        0
# city          0
# state         0
# zip           0
# lat           0
# long          0
# city_pop      0
# job           0
# unix_time     0
# merch_lat     0
# merch_long    0
# is_fraud      0
# dtype: int64

# %%
encoder = LabelEncoder()

# %%
cc_data['category'] = encoder.fit_transform(cc_data['category'])
cc_data['gender'] = encoder.fit_transform(cc_data['gender'])
cc_data['city'] = encoder.fit_transform(cc_data['city'])
cc_data['state'] = encoder.fit_transform(cc_data['state'])
cc_data['job'] = encoder.fit_transform(cc_data['job'])

# %%
cc_data.head(3)
# Out:
#    category    amt  gender  city  state    zip      lat      long  city_pop  \
# 0        10   2.86       1   157     39  29209  33.9659  -80.9355    333497
# 1        10  29.84       0    16     43  84002  40.3207 -110.4360       302
# 2         5  41.28       0    61     33  11710  40.6729  -73.5365     34496
#
#    job   unix_time  merch_lat  merch_long  is_fraud
# 0  275  1371816865  33.986391  -81.200714         0
# 1  392  1371816873  39.450498 -109.960431         0
# 2  259  1371816893  40.495810  -74.196111         0

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cc_data.corr(), cmap= 'Reds', annot = True,  fmt = ".2f")
# Out:
# <Axes: >

# %%
sns.set_style("darkgrid")
sns.countplot(data = cc_data, x = "gender", hue = "gender")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.set_style("darkgrid")
sns.countplot(data = cc_data, x = "is_fraud", hue = "is_fraud")
# Out:
# <Axes: xlabel='is_fraud', ylabel='count'>

# %%
X =  cc_data.drop(columns='is_fraud', axis = 1)
Y =  cc_data['is_fraud']

# %%
X.head(2)
# Out:
#    category    amt  gender  city  state    zip      lat      long  city_pop  \
# 0        10   2.86       1   157     39  29209  33.9659  -80.9355    333497
# 1        10  29.84       0    16     43  84002  40.3207 -110.4360       302
#
#    job   unix_time  merch_lat  merch_long
# 0  275  1371816865  33.986391  -81.200714
# 1  392  1371816873  39.450498 -109.960431

# %%
Y.head(4)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# Name: is_fraud, dtype: int64

# %%
X_train,X_test,Y_train,Y_test =train_test_split(X,Y,test_size = 0.2, stratify = Y, random_state =2)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((444575, 13), (111144, 13), (444575,), (111144,))
